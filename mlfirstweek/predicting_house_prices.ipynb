# %% [markdown]
# #Fire up graphlab create

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# #Load some house sales data
#
# Dataset is from house sales in King County, the region where the city of Seattle, WA is located.

# %%
sales = pd.read_csv('home_data.csv')

# %%
sales
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000   221900         3       1.00         1180
# 1      6414100192  20141209T000000   538000         3       2.25         2570
# 2      5631500400  20150225T000000   180000         2       1.00          770
# 3      2487200875  20141209T000000   604000         4       3.00         1960
# 4      1954400510  20150218T000000   510000         3       2.00         1680
# 5      7237550310  20140512T000000  1225000         4       4.50         5420
# 6      1321400060  20140627T000000   257500         3       2.25         1715
# 7      2008000270  20150115T000000   291850         3       1.50         1060
# 8      2414600126  20150415T000000   229500         3       1.00         1780
# 9      3793500160  20150312T000000   323000         3       2.50         1890
# 10     1736800520  20150403T000000   662500         3       2.50         3560
# ...

# %% [markdown]
# #Exploring the data for housing sales

# %% [markdown]
# The house price is correlated with the number of square feet of living space.

# %%
#sales.plot(kind = 'scatter', x = "sqft_living", y = 'price')
plt.figure(figsize=(20,10))
plt.plot(sales['sqft_living'], sales['price'], '+')

# %% [markdown]
# #Create a simple regression model of sqft_living to price

# %% [markdown]
# Split data into training and testing.
# We use seed=0 so that everyone running this notebook gets the same results.  In practice, you may set a random seed (or let GraphLab Create pick a random seed for you).

# %%
from sklearn.cross_validation import train_test_split
train_data, test_data = train_test_split(sales, train_size = 0.8)

# %% [markdown]
# ##Build the regression model using only sqft_living as a feature

# %%
from sklearn import linear_model
sqft_model = linear_model.LinearRegression()
sqft_model.fit(np.array(train_data[['sqft_living']]), np.array(train_data['price']))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# #Evaluate the simple model

# %%
print test_data['price'].mean()
# Out:
# 540200.908166

# %%
predicted = sqft_model.predict(np.array(test_data[['sqft_living']]))
from sklearn.metrics import mean_squared_error
from math import sqrt
print sqrt(mean_squared_error(np.array(test_data['price']), predicted))
# Out:
# 257692.345553

# %% [markdown]
# RMSE of about \$255,170!

# %% [markdown]
# #Let's show what our predictions look like

# %% [markdown]
# Matplotlib is a Python plotting library that is also useful for plotting.  You can install it with:
#
# 'pip install matplotlib'

# %%
plt.figure(figsize=(20,10))
plt.plot(test_data['sqft_living'], test_data['price'], '+', test_data['sqft_living'], predicted, '*')

# %% [markdown]
# Above:  blue dots are original data, green line is the prediction from the simple regression.
#
# Below: we can view the learned regression coefficients.

# %%
print sqft_model.intercept_,' ', sqft_model.coef_
#sqft_model.get('coefficients)
# Out:
# -40336.9493192   [ 278.78809024]

# %% [markdown]
# #Explore other features in the data
#
# To build a more elaborate model, we will explore using more features.

# %%
my_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']

# %%
sales[my_features]
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  zipcode
# 0             3       1.00         1180      5650     1.0    98178
# 1             3       2.25         2570      7242     2.0    98125
# 2             2       1.00          770     10000     1.0    98028
# 3             4       3.00         1960      5000     1.0    98136
# 4             3       2.00         1680      8080     1.0    98074
# 5             4       4.50         5420    101930     1.0    98053
# 6             3       2.25         1715      6819     2.0    98003
# 7             3       1.50         1060      9711     1.0    98198
# 8             3       1.00         1780      7470     1.0    98146
# 9             3       2.50         1890      6560     2.0    98038
# 10            3       2.50         3560      9796     1.0    98007
# 11            2       1.00         1160      6000     1.0    98115
# 12            3       1.00         1430     19901     1.5    98028
# ...

# %%
plt.figure(figsize = (10,10))
plt.plot(sales['zipcode'], sales['price'], '*')
#sales.plot(kind = 'box', x='zipcode', y= 'price')
#learn how to do box plot in pandas

# %% [markdown]
# Pull the bar at the bottom to view more of the data.
#
# 98039 is the most expensive zip code.

# %% [markdown]
# #Build a regression model with more features

# %%
my_feature_model = linear_model.LinearRegression()
my_feature_model.fit(np.array(train_data[my_features]), np.array(train_data['price']))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print my_features
# Out:
# ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']

# %% [markdown]
# ##Comparing the results of the simple model with adding more features

# %%
predictedsec = my_feature_model.predict(np.array(test_data[my_features]))
print sqrt(mean_squared_error(np.array(test_data['price']), predicted))
print sqrt(mean_squared_error(np.array(test_data['price']), predictedsec))
#why there is such a big difference ?
# Out:
# 257692.345553
# 251133.386974

# %% [markdown]
# The RMSE goes down from \$255,170 to \$179,508 with more features.

# %% [markdown]
# #Apply learned models to predict prices of 3 houses

# %% [markdown]
# The first house we will use is considered an "average" house in Seattle.

# %%
house1 = sales[sales['id']==5309101200]

# %%
house1
# Out:
#               id             date   price  bedrooms  bathrooms  sqft_living  \
# 1054  5309101200  20140605T000000  620000         4       2.25         2400
#
#       sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 1054      5350     1.5           0     0     ...          7        1460
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat    long  \
# 1054            940      1929             0    98117  47.6763 -122.37
#
#       sqft_living15  sqft_lot15
# 1054           1250        4880
#
# [1 rows x 21 columns]

# %% [markdown]
# <img src="http://info.kingcounty.gov/Assessor/eRealProperty/MediaHandler.aspx?Media=2916871">

# %%
print house1['price']
house1
# Out:
# 1054    620000
# Name: price, dtype: int64
#               id             date   price  bedrooms  bathrooms  sqft_living  \
# 1054  5309101200  20140605T000000  620000         4       2.25         2400
#
#       sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 1054      5350     1.5           0     0     ...          7        1460
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat    long  \
# 1054            940      1929             0    98117  47.6763 -122.37
#
#       sqft_living15  sqft_lot15
# 1054           1250        4880
#
# [1 rows x 21 columns]

# %%
print sqft_model.predict(np.array(house1[['sqft_living']]))
# Out:
# [ 628754.46726831]

# %%
print my_feature_model.predict(np.array(house1[my_features]))
# Out:
# [ 630606.49072764]

# %% [markdown]
# In this case, the model with more features provides a worse prediction than the simpler model with only 1 feature.  However, on average, the model with more features is better.

# %% [markdown]
# ##Prediction for a second, fancier house
#
# We will now examine the predictions for a fancier house.

# %%
house2 = sales[sales['id']==1925069082]

# %%
house2
# Out:
#               id             date    price  bedrooms  bathrooms  sqft_living  \
# 1361  1925069082  20150511T000000  2200000         5       4.25         4640
#
#       sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 1361     22703       2           1     4     ...          8        2860
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1361           1780      1952             0    98052  47.6393 -122.097
#
#       sqft_living15  sqft_lot15
# 1361           3140       14200
#
# [1 rows x 21 columns]

# %% [markdown]
# <img src="https://ssl.cdn-redfin.com/photo/1/bigphoto/302/734302_0.jpg">

# %%
print sqft_model.predict(np.array(house2[['sqft_living']]))
# Out:
# [ 1253239.78941668]

# %%
print my_feature_model.predict(np.array(house2[my_features]))
# Out:
# [ 1258997.06796777]

# %% [markdown]
# In this case, the model with more features provides a better prediction.  This behavior is expected here, because this house is more differentiated by features that go beyond its square feet of living space, especially the fact that it's a waterfront house.

# %% [markdown]
# ##Last house, super fancy
#
# Our last house is a very large one owned by a famous Seattleite.

# %%
bill_gates = {'bedrooms':[8], 
              'bathrooms':[25], 
              'sqft_living':[50000], 
              'sqft_lot':[225000],
              'floors':[4], 
              'zipcode':['98039'], 
              'condition':[10], 
              'grade':[10],
              'waterfront':[1],
              'view':[4],
              'sqft_above':[37500],
              'sqft_basement':[12500],
              'yr_built':[1994],
              'yr_renovated':[2010],
              'lat':[47.627606],
              'long':[-122.242054],
              'sqft_living15':[5000],
              'sqft_lot15':[40000]}

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Bill_gates%27_house.jpg/2560px-Bill_gates%27_house.jpg">

# %%
print my_feature_model.predict(np.array(pd.DataFrame(bill_gates)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-34c81f0742bb> in <module>()
# ----> 1 print my_feature_model.predict(np.array(pd.DataFrame(bill_gates)))
#
# /Library/Python/2.7/site-packages/sklearn/linear_model/base.pyc in predict(self, X)
#     198             Returns predicted values.
#     199         """
# --> 200         return self._decision_function(X)
#     201
#     202     _center_data = staticmethod(center_data)
#
# /Library/Python/2.7/site-packages/sklearn/linear_model/base.pyc in _decision_function(self, X)
#     183         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     184         return safe_sparse_dot(X, self.coef_.T,
# --> 185                                dense_output=True) + self.intercept_
#     186
#     187     def predict(self, X):
#
# ...

# %% [markdown]
# The model predicts a price of over $13M for this house! But we expect the house to cost much more.  (There are very few samples in the dataset of houses that are this fancy, so we don't expect the model to capture a perfect prediction here.)
